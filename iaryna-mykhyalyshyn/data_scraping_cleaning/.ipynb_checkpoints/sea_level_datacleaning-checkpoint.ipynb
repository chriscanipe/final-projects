# %%
import os
import glob
import pandas as pd
import numpy as np

path = "/Users/iaryna/Documents/Mizzou/AppDEV/final_project/line_final/data_scraping_cleaning/all_30years"
allfiles = glob.glob(os.path.join(path,"*.csv"))
count = 1



for file_ in allfiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    df.columns = ['year', 'month', 'day', 'level'] #add column names
    df = df[(df.year >= 1984) & (df.year < 2015)] #filter 50 years
    
    name_string = file_.split('/') #add city name
    city_name = name_string[8].replace("_", " ")
    city_name = city_name.replace(".csv", "")
#     count +=1

    df = df.groupby('year') #group by year
    df = df["level"].mean().round(1).reset_index().rename(columns={'level': 'level_norm'})
    starting_value = df['level_norm'].iloc[0] #get starting value
    


    df["level_norm"] = df.level_norm - starting_value
    df["city"] = city_name
#     df["count"] = count
    
#     df.index = df.index + 1 #start index from 1 for heatmap
    df.to_csv(file_)
    
    
    # get list of names
    last_value = df.level_norm.iloc[-1]
    print city_name,",", last_value
# Out:
# data scraping cleaning , 52.2
# data scraping cleaning , 138.9
# data scraping cleaning , -25.1
# data scraping cleaning , -67.9
# data scraping cleaning , 18.5
# data scraping cleaning , 105.5
# data scraping cleaning , 10.1
# data scraping cleaning , 47.1
# data scraping cleaning , 93.4
# data scraping cleaning , 128.5
# data scraping cleaning , 10.8
# data scraping cleaning , 108.6
# data scraping cleaning , 134.5
# data scraping cleaning , 25.0
# data scraping cleaning , 127.5
# data scraping cleaning , 54.7
# data scraping cleaning , 87.1
# data scraping cleaning , 149.5
# data scraping cleaning , 94.4
# data scraping cleaning , 186.7
# data scraping cleaning , 10.9
# data scraping cleaning , 9.8
# data scraping cleaning , -23.7
# data scraping cleaning , 91.9
# data scraping cleaning , 99.5
# data scraping cleaning , 99.1
# data scraping cleaning , 15.5
# data scraping cleaning , 123.9
# data scraping cleaning , 39.0
# data scraping cleaning , 62.9
# data scraping cleaning , 111.8
# data scraping cleaning , 87.1
# data scraping cleaning , 45.3
# data scraping cleaning , 154.2
# data scraping cleaning , 57.0
# data scraping cleaning , 194.1
# data scraping cleaning , 86.5
# data scraping cleaning , 8.7
# data scraping cleaning , 171.4
# data scraping cleaning , 107.0
# data scraping cleaning , 3.3
# data scraping cleaning , -55.7
# data scraping cleaning , 71.9
# data scraping cleaning , 126.0
# data scraping cleaning , 25.4
# data scraping cleaning , 7.8
# data scraping cleaning , 56.3
# data scraping cleaning , -59.5
# data scraping cleaning , 34.9
# data scraping cleaning , -14.0
# data scraping cleaning , 143.1
# data scraping cleaning , 56.7
# data scraping cleaning , -97.6
# data scraping cleaning , 123.8
# data scraping cleaning , 86.4
# data scraping cleaning , -312.3
# data scraping cleaning , 241.2
# data scraping cleaning , 230.6
